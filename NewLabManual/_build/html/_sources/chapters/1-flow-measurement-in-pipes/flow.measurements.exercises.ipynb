# %% [markdown]
# Exercise Set

# %% [markdown]
# 1. The figure below depicts a 6 in. orifice that is installed in a 12 in. pipe.
#
# ![](orifice.in.pipe.one.png)
#
# Determine:
# - The discharge of water in the pipe.
#
# ---

# %% [markdown]
# 2. The figure below depicts an orifice installed in a pipe with manometer (piezometers) connected.
#
# ![](orifice.in.pipe.two.png)
#
# Determine:
# - The discharge of water (T 60°F) in the pipe.
#
# ---

# %% [markdown]
# 3. Water (20°C) is flowing through the 5 cm orifice pictured below
#
# ![](orifice.in.pipe.three.png)
#
# Determine:
# - The discharge in the pipe
#
# ---

# %% [markdown]
# 4. The figure below depicts a venturi meter.
#
# ![](venturi.meter.one.png)
#
# The pressure differential across this venturi meter is 100 kPa.
#
# Determine:
# - The discharge of water in the pipe.
#
# ---

# %% [markdown]
# 5. The differential-pressure gage on the venturi meter depicted below reads 45 kPa.
#
# ![](venturi.meter.two.png)
#
# For $d = 20$ cm, $D = 40$ cm, and $h = 80$ cm.
#
# Determine:
# - Discharge of gasoline ($S = 0.69$; $\mu = 3\times10^{–4}~\frac{N \cdot s}{ m^2}$) in the pipe.
#
# ---

# %% [markdown]
# 6. A rotameter is used to measure the flow rate of a fluid with a density of $1.0 \frac{kg}{ m^3}$. The scale on the rotameter indicates $5 \frac{l}{s}$. The rotameter is calibrated for a fluid with a density of $1.2 \frac{kg}{ m^3}$.
#
# Determine:
# - The actual flow rate of the fluid (in liters per second).
