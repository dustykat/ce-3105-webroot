# %% [markdown]
# # Report Evaluation Rubric
#
# **Total: 100 points**
# - Format & Presentation: 30 points
# - Grammar & Clarity: 20 points
# - Technical Content: 50 points
#
# ---
#
# ## I. Format & Presentation (30 points)
#
# | Criterion | Points |
# |----------|--------|
# | Proper section headings used (Title/Objectives, Theory, Materials, Setup, Procedure, Data, Analysis, Conclusion) | 6 |
# | Equations clearly typeset and variables defined | 4 |
# | Tables and figures labeled and referenced in the text | 6 |
# | Units consistently included for all measurements and variables | 4 |
# | Overall visual clarity and structure (indents, spacing, font, logical flow) | 5 |
# | Citations and references properly formatted and included | 5 |
# | **Subtotal** | **/30** |
#
# ---
#
# ## II. Grammar & Clarity (20 points)
#
# | Criterion | Points |
# |----------|--------|
# | Sentence-level grammar and mechanics (spelling, punctuation, structure) | 6 |
# | Clarity and conciseness of writing (avoidance of redundancy, clear explanation) | 6 |
# | Correct and consistent use of technical terms | 4 |
# | Smooth transitions between sections and logical sequencing of ideas | 4 |
# | **Subtotal** | **/20** |
#
# ---
#
# ## III. Technical Content (50 points)
#
# | Criterion | Points |
# |----------|--------|
# | **Model Presentation**: Correct identification of the governing equation and model assumptions | 8 |
# | **Data Collection**: Sufficient trials, completeness, and proper documentation | 8 |
# | **Calculations**: Proper use of formulas and appropriate units | 8 |
# | **Graphing/Plotting**: Calibration curves or result graphs properly labeled and interpreted | 8 |
# | **Analysis**: Comparison of predicted vs. measured outcomes, error analysis, and explanation of discrepancies | 10 |
# | **Conclusion**: Thoughtful summary, limitations, and future improvements clearly stated | 8 |
# | **Subtotal** | **/50** |
#
# ---
#
# ## ✅ Final Score:
#
# - **Format:** ____ / 30
# - **Grammar:** ____ / 20
# - **Technical Content:** ____ / 50
#
# **Total:** ____ / 100
#
# ---

# %% [markdown]
# ## Additional Guidance
#
# Submission Guidelines for Lab Reports
#
# The instructor uses a Language Learning Model (OnPrem.LLM; Modular, privacy-first, local document & prompt handling) to generate feedback and provide an initial score for your work. To ensure accurate evaluation and maximize your score:
#
# ### File Naming Convention
# Follow the explicit file name convention provided by the instructor (e.g., LastName_FirstName_AssignmentName.pdf). This ensures your work is identifiable.
#
# ### File Format
# Submit your work as a PDF file. If your assignment involves computational scripts or code, include them as clearly formatted appendices in the same PDF or submit a zipped folder containing both the PDF and the scripts.
#
# ### Structure Your Document
#
# Use the report format provided.
#
# ### Use Consistent Formatting
#
# - Use a standard font (e.g., Times New Roman, 12pt) and 1.5x line spacing.
# - Use headings for major sections (e.g., "Problem 1," "Solution").
# - Label and reference all figures, tables, and equations.
#
# ### Code Integration
#
# - If applicable, embed short code snippets directly into the document and ensure they are legible.
# - For longer scripts, attach them in an appendix or as separate files.
#
# ### Calculations and Units
#
# - Show all steps in your calculations (representative calculations are preferable -  I assume you will use a script or spreadsheet for repetitive calculations).
# - Use consistent units throughout and verify that units are included in all results.
#
# ### Graphs and Diagrams
#
# - Clearly label all axes and include titles. [**Graphics Conventions (link)**](http://54.243.252.9/engr-1330-webroot/engr1330jb/_build/html/lessons/lesson14/lesson14.html)
# - Add legends if multiple datasets are plotted.
# - Ensure diagrams are annotated and relevant to your solution.
#
# ### References
#
# Cite all external materials used (e.g., textbooks, research papers, or online resources).

# %% [markdown]
# ## Section End
